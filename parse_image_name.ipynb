# %%
import os
path = "/content/drive/MyDrive/data/c/images/"
dir_list = os.listdir(path)
 
count = 0

# prints all files
for i in dir_list:
  print(os.path.splitext(i)[0])
  count = count + 1
  
#print(dir_list)
print(count)
# Out:
# IMG_4777
# IMG_4776
# IMG_4775
# IMG_4779
# IMG_4778
# IMG_4780
# IMG_4783
# IMG_4784
# IMG_4782
# IMG_4785
# IMG_4781
# IMG_4787
# IMG_4786
# IMG_4791
# IMG_4792
# IMG_4790
# IMG_4789
# IMG_4788
# IMG_4793
# IMG_4794
# IMG_4795
# IMG_4797
# IMG_4798
# IMG_4796
# IMG_4803
# IMG_4801
# IMG_4800
# IMG_4802
# IMG_4799
# IMG_4804
# IMG_4805
# IMG_4806
# IMG_4808
# IMG_4809
# IMG_4807
# IMG_4810
# IMG_4813
# IMG_4814
# IMG_4812
# IMG_4811
# IMG_4816
# IMG_4815
# IMG_4820
# IMG_4819
# IMG_4818
# IMG_4822
# IMG_4821
# IMG_4823
# IMG_4824
# IMG_4825
# IMG_4826
# IMG_4827
# IMG_4828
# IMG_5116
# IMG_5115
# IMG_5114
# IMG_5118
# IMG_5119
# IMG_5117
# IMG_5121
# IMG_5122
# IMG_5120
# IMG_5124
# IMG_5125
# IMG_5123
# IMG_5126
# IMG_5127
# IMG_5129
# IMG_5128
# IMG_5130
# IMG_5132
# IMG_5131
# IMG_5135
# IMG_5133
# IMG_5134
# IMG_5136
# IMG_5137
# IMG_5138
# IMG_5139
# IMG_5140
# IMG_5141
# IMG_5142
# IMG_5144
# IMG_5145
# IMG_5146
# IMG_5143
# IMG_5147
# IMG_5149
# IMG_5150
# IMG_5152
# ...
